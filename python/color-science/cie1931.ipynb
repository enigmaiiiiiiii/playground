# %%
import colour

RGB = colour.read_image('./ACES2065-1_ColorChecker2014.exr')

colour.plotting.plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931(
    RGB[::5, ::5, ...], colourspace='ACES2065-1', colourspaces=['sRGB']);

# Customising the scatter appearance, the dict is passed to
# the "matplotlib.pyplot.scatter" definition.
colour.plotting.plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931(
    RGB[::5, ::5, ...], colourspace='ACES2065-1', colourspaces=['sRGB'],
    scatter_kwargs={'c': 'k', 'marker': '+'});
# Out:
# /Users/dopamine/Code/MyRepository/playground/python/.venv/lib/python3.11/site-packages/colour/utilities/verbose.py:262: ColourUsageWarning: The "ALEXA Wide Gamut" RGB colourspace has been renamed to "ARRI Wide Gamut 3" for consistency with ARRI's new naming convention.
#   warn(*args, **kwargs)  # noqa: B028
# /Users/dopamine/Code/MyRepository/playground/python/.venv/lib/python3.11/site-packages/colour/utilities/verbose.py:262: ColourUsageWarning: The "CIE 2012 2 Degree Standard Observer" has been renamed to "CIE 2015 2 Degree Standard Observer" for consistency with the official CIE name which was adopted in 2015.
#   warn(*args, **kwargs)  # noqa: B028
# /Users/dopamine/Code/MyRepository/playground/python/.venv/lib/python3.11/site-packages/colour/utilities/verbose.py:262: ColourUsageWarning: The "CIE 2012 10 Degree Standard Observer" has been renamed to "CIE 2015 10 Degree Standard Observer" for consistency with the official CIE name which was adopted in 2015.
#   warn(*args, **kwargs)  # noqa: B028
